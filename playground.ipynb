# %% [markdown]
# # Dataset examples

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch

from dataset.dataset import PepeDataset
from config import Paths, Config

# %%
dataset_name = 'pepe'
dataset = PepeDataset(dataset_name, Paths())

sample_num = np.random.randint(len(dataset))
print(f'Sample num is {sample_num}')

sample = dataset[sample_num]
image = sample.numpy().transpose((1, 2, 0))
image = (image + 1) / 2
plt.imshow(image)
plt.show()
# Out:
# Sample num is 2263

# %%
plt.hist(sample.flatten().numpy(), bins=50)
plt.show()

# %%
dataset_name = 'celeba'
dataset = PepeDataset(dataset_name, Paths())

sample_num = np.random.randint(len(dataset))
print(f'Sample num is {sample_num}')

sample = dataset[sample_num]
image = sample.numpy().transpose((1, 2, 0))
image = (image + 1) / 2
plt.imshow(image)
plt.show()
# Out:
# Sample num is 114676

# %%
plt.hist(sample.flatten().numpy(), bins=50)
plt.show()

# %%
dataset_name = 'twitch_emotes'
dataset = PepeDataset(dataset_name, Paths())

sample_num = np.random.randint(len(dataset))
print(f'Sample num is {sample_num}')

sample = dataset[sample_num]
image = sample.numpy().transpose((1, 2, 0))
image = (image + 1) / 2
plt.imshow(image)
plt.show()
# Out:
# Sample num is 14526

# %%
plt.hist(sample.flatten().numpy(), bins=50)
plt.show()

# %% [markdown]
# # Collect twitch_emotes dataset using API's

# %%
import requests
from PIL import Image
from io import BytesIO

# %%
req = requests.request('GET', 'https://api.betterttv.net/3/cached/emotes/global')
req.json()
# Out:
# [{'id': '54fa8f1401e468494b85b537',
#   'code': ':tf:',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19'},
#  {'id': '54fa8fce01e468494b85b53c',
#   'code': 'CiGrip',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19'},
#  {'id': '54fa903b01e468494b85b53f',
#   'code': 'DatSauce',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19'},
#  {'id': '54fa909b01e468494b85b542',
#   'code': 'ForeverAlone',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19'},
#  {'id': '54fa90ba01e468494b85b543',
#   'code': 'GabeN',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19'},
#  {'id': '54fa90f201e468494b85b545',
#   'code': 'HailHelix',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19'},
#  {'id': '54fa932201e468494b85b555',
#   'code': 'ShoopDaWhoop',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19'},
#  {'id': '54fab45f633595ca4c713abc',
#   'code': 'M&Mjc',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19',
#   'width': 36,
#   'height': 30},
#  {'id': '54fab7d2633595ca4c713abf',
#   'code': 'bttvNice',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19',
#   'width': 42,
#   'height': 28},
#  {'id': '54fa935601e468494b85b557',
#   'code': 'TwaT',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19'},
#  {'id': '54fa99b601e468494b85b55d',
#   'code': 'WatChuSay',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19'},
#  {'id': '566ca11a65dbbdab32ec0558',
#   'code': 'tehPoleCat',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19',
#   'width': 21,
#   'height': 28},
#  {'id': '566ca1a365dbbdab32ec055b',
#   'code': 'AngelThump',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19',
#   'width': 84,
#   'height': 28},
#  {'id': '54fbefeb01abde735115de5b',
#   'code': 'TaxiBro',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19',
#   'width': 87,
#   'height': 30},
#  {'id': '54fbf00a01abde735115de5c',
#   'code': 'BroBalt',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19',
#   'width': 46,
#   'height': 30},
#  {'id': '54fbf09c01abde735115de61',
#   'code': 'CandianRage',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19'},
#  {'id': '55028cd2135896936880fdd7',
#   'code': 'D:',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19'},
#  {'id': '550352766f86a5b26c281ba2',
#   'code': 'VisLaud',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19'},
#  {'id': '550b344bff8ecee922d2a3c1',
#   'code': 'KaRappa',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19'},
#  {'id': '566ca00f65dbbdab32ec0544',
#   'code': 'FishMoley',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19',
#   'width': 56,
#   'height': 34},
#  {'id': '566ca02865dbbdab32ec0547',
#   'code': 'Hhhehehe',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19'},
#  {'id': '566ca04265dbbdab32ec054a',
#   'code': 'KKona',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19',
#   'width': 25,
#   'height': 34},
#  {'id': '566ca09365dbbdab32ec0555',
#   'code': 'PoleDoge',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19'},
#  {'id': '553b48a21f145f087fc15ca6',
#   'code': 'sosGame',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19'},
#  {'id': '55471c2789d53f2d12781713',
#   'code': 'CruW',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19'},
#  {'id': '555015b77676617e17dd2e8e',
#   'code': 'RarePepe',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '54f93e618edd5fcd455f213f'},
#  {'id': '555981336ba1901877765555',
#   'code': 'haHAA',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '54f93e3e8edd5fcd455f213d'},
#  {'id': '55b6524154eefd53777b2580',
#   'code': 'FeelsBirthdayMan',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19',
#   'width': 19,
#   'height': 28},
#  {'id': '55f324c47f08be9f0a63cce0',
#   'code': 'RonSmug',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19',
#   'width': 21,
#   'height': 28},
#  {'id': '560577560874de34757d2dc0',
#   'code': 'KappaCool',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19',
#   'width': 22,
#   'height': 28},
#  {'id': '566c9fc265dbbdab32ec053b',
#   'code': 'FeelsBadMan',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19'},
#  {'id': '566c9f3b65dbbdab32ec052e',
#   'code': 'bUrself',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19'},
#  {'id': '566c9f6365dbbdab32ec0532',
#   'code': 'ConcernDoge',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19',
#   'width': 25,
#   'height': 28},
#  {'id': '566c9fde65dbbdab32ec053e',
#   'code': 'FeelsGoodMan',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19'},
#  {'id': '566c9ff365dbbdab32ec0541',
#   'code': 'FireSpeed',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19',
#   'width': 53,
#   'height': 28},
#  {'id': '566ca06065dbbdab32ec054e',
#   'code': 'NaM',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19',
#   'width': 38,
#   'height': 40},
#  {'id': '566ca38765dbbdab32ec0560',
#   'code': 'SourPls',
#   'imageType': 'gif',
#   'animated': True,
#   'userId': '5561169bd6b9d206222a8c19'},
#  {'id': '566dde0e65dbbdab32ec068f',
#   'code': 'FeelsSnowMan',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19',
#   'width': 31,
#   'height': 30},
#  {'id': '566decae65dbbdab32ec0699',
#   'code': 'FeelsSnowyMan',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19',
#   'width': 31,
#   'height': 30},
#  {'id': '567b00c61ddbe1786688a633',
#   'code': 'LuL',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '54f93e618edd5fcd455f213f'},
#  {'id': '56901914991f200c34ffa656',
#   'code': 'SaltyCorn',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19',
#   'width': 28,
#   'height': 30},
#  {'id': '56e9f494fff3cc5c35e5287e',
#   'code': 'monkaS',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '55bfba180baa41467919aabf'},
#  {'id': '56f5be00d48006ba34f530a4',
#   'code': 'VapeNation',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '55583bc00c72ab1d77d8b9b7'},
#  {'id': '56fa09f18eff3b595e93ac26',
#   'code': 'ariW',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '54ee2465b822020506c52a52'},
#  {'id': '5709ab688eff3b595e93c595',
#   'code': 'notsquishY',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '54ee2465b822020506c52a52',
#   'width': 24,
#   'height': 28},
#  {'id': '5733ff12e72c3c0814233e20',
#   'code': 'FeelsAmazingMan',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19'},
#  {'id': '573d38b50ffbf6cc5cc38dc9',
#   'code': 'DuckerZ',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19',
#   'width': 37,
#   'height': 28},
#  {'id': '59cf182fcbe2693d59d7bf46',
#   'code': 'SqShy',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '54ee2465b822020506c52a52'},
#  {'id': '58d2e73058d8950a875ad027',
#   'code': 'Wowee',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '5561169bd6b9d206222a8c19'},
#  {'id': '5dc36a8db537d747e37ac187',
#   'code': 'WubTF',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '54f93e3e8edd5fcd455f213d'},
#  {'id': '5e76d2ab8c0f5c3723a9a87d',
#   'code': 'cvR',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '54ee2465b822020506c52a52'},
#  {'id': '5e76d2d2d112fc372574d222',
#   'code': 'cvL',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '54ee2465b822020506c52a52'},
#  {'id': '5e76d338d6581c3724c0f0b2',
#   'code': 'cvHazmat',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '54ee2465b822020506c52a52'},
#  {'id': '5e76d399d6581c3724c0f0b8',
#   'code': 'cvMask',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '54ee2465b822020506c52a52'},
#  {'id': '5ffdf28dc96152314ad63960',
#   'code': 'DogChamp',
#   'imageType': 'png',
#   'animated': False,
#   'userId': '54f92c8c34fde4ae450d8d26'}]

# %%
len(req.json())
# Out:
# 55

# %%
req = requests.request('GET', 'https://cdn.betterttv.net/emote/5ffdf28dc96152314ad63960/3x')
Image.open(BytesIO(req.content))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=112x112>

# %%
req = requests.request('GET', 'https://api.frankerfacez.com/v1/emoticons')
req.json()
# Out:
# {'_pages': 6245,
#  '_total': 312219,
#  'emoticons': [{'id': 729052,
#    'name': 'monkaSHAKE',
#    'height': 32,
#    'width': 32,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1541672, 'name': 'jostro_', 'display_name': 'JoStro_'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729052/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729052/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729052/4'},
#    'animated': {'1': 'https://cdn.frankerfacez.com/emote/729052/animated/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729052/animated/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729052/animated/4'},
#    'status': 1,
#    'usage_count': 0,
#    'created_at': '2023-05-30T13:41:19.918Z',
#    'last_updated': '2023-05-30T13:45:37.409Z'},
#   {'id': 729051,
#    'name': 'eseareOkay',
#    'height': 32,
#    'width': 32,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1508385,
#     'name': 'absoluteese',
#     'display_name': 'AbsoluteEse'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729051/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729051/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729051/4'},
#    'status': 1,
#    'usage_count': 0,
#    'created_at': '2023-05-30T08:12:49.909Z',
#    'last_updated': '2023-05-30T13:46:34.791Z'},
#   {'id': 729050,
#    'name': 'eseareSlurp',
#    'height': 32,
#    'width': 32,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1508385,
#     'name': 'absoluteese',
#     'display_name': 'AbsoluteEse'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729050/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729050/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729050/4'},
#    'status': 1,
#    'usage_count': 0,
#    'created_at': '2023-05-30T08:12:49.871Z',
#    'last_updated': '2023-05-30T13:46:34.791Z'},
#   {'id': 729049,
#    'name': 'eseareEwww',
#    'height': 32,
#    'width': 32,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1508385,
#     'name': 'absoluteese',
#     'display_name': 'AbsoluteEse'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729049/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729049/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729049/4'},
#    'status': 1,
#    'usage_count': 0,
#    'created_at': '2023-05-30T08:12:49.856Z',
#    'last_updated': '2023-05-30T13:46:34.791Z'},
#   {'id': 729048,
#    'name': 'eseareYawn',
#    'height': 32,
#    'width': 32,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1508385,
#     'name': 'absoluteese',
#     'display_name': 'AbsoluteEse'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729048/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729048/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729048/4'},
#    'status': 1,
#    'usage_count': 0,
#    'created_at': '2023-05-30T08:12:49.698Z',
#    'last_updated': '2023-05-30T13:46:34.791Z'},
#   {'id': 729046,
#    'name': 'jermaStung',
#    'height': 32,
#    'width': 23,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1087834, 'name': 'fern_i_i', 'display_name': 'fern_i_i'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729046/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729046/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729046/4'},
#    'status': 1,
#    'usage_count': 1,
#    'created_at': '2023-05-30T06:55:00.844Z',
#    'last_updated': '2023-05-30T13:45:37.409Z'},
#   {'id': 729045,
#    'name': 'StarDoorge',
#    'height': 32,
#    'width': 40,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 818615,
#     'name': 'not_doopsie',
#     'display_name': 'Not_Doopsie'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729045/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729045/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729045/4'},
#    'status': 1,
#    'usage_count': 1,
#    'created_at': '2023-05-30T04:31:32.300Z',
#    'last_updated': '2023-05-30T13:45:37.409Z'},
#   {'id': 729044,
#    'name': 'GooseyLove',
#    'height': 32,
#    'width': 34,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 726271,
#     'name': 'galedagenhart',
#     'display_name': 'GaleDagenhart'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729044/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729044/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729044/4'},
#    'status': 1,
#    'usage_count': 1,
#    'created_at': '2023-05-30T04:08:05.827Z',
#    'last_updated': '2023-05-30T13:45:37.409Z'},
#   {'id': 729043,
#    'name': 'LETSFUCKINGSHIT',
#    'height': 28,
#    'width': 28,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1169644,
#     'name': 'princesshopey',
#     'display_name': 'princesshopey'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729043/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729043/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729043/4'},
#    'status': 1,
#    'usage_count': 1,
#    'created_at': '2023-05-30T04:07:50.949Z',
#    'last_updated': '2023-05-30T13:45:37.409Z'},
#   {'id': 729042,
#    'name': 'EZsip',
#    'height': 28,
#    'width': 28,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1169644,
#     'name': 'princesshopey',
#     'display_name': 'princesshopey'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729042/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729042/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729042/4'},
#    'status': 1,
#    'usage_count': 1,
#    'created_at': '2023-05-30T04:01:57.223Z',
#    'last_updated': '2023-05-30T13:45:37.409Z'},
#   {'id': 729041,
#    'name': 'HOPIUM',
#    'height': 28,
#    'width': 28,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1169644,
#     'name': 'princesshopey',
#     'display_name': 'princesshopey'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729041/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729041/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729041/4'},
#    'status': 1,
#    'usage_count': 1,
#    'created_at': '2023-05-30T04:01:57.220Z',
#    'last_updated': '2023-05-30T13:45:37.409Z'},
#   {'id': 729040,
#    'name': 'joejoe21L33tle',
#    'height': 32,
#    'width': 32,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1542505,
#     'name': 'joejoeradio',
#     'display_name': 'JoeJoeRadio'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729040/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729040/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729040/4'},
#    'status': 1,
#    'usage_count': 1,
#    'created_at': '2023-05-30T03:45:18.179Z',
#    'last_updated': '2023-05-30T13:45:37.409Z'},
#   {'id': 729039,
#    'name': 'joejoe21Sh1ong',
#    'height': 32,
#    'width': 32,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1542505,
#     'name': 'joejoeradio',
#     'display_name': 'JoeJoeRadio'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729039/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729039/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729039/4'},
#    'status': 1,
#    'usage_count': 3,
#    'created_at': '2023-05-30T02:34:52.191Z',
#    'last_updated': '2023-05-30T13:45:37.409Z'},
#   {'id': 729037,
#    'name': 'AngryDrong',
#    'height': 32,
#    'width': 30,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 35055, 'name': 'adidino', 'display_name': 'Adidino'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729037/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729037/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729037/4'},
#    'status': 1,
#    'usage_count': 0,
#    'created_at': '2023-05-29T22:05:08.049Z',
#    'last_updated': '2023-05-30T13:45:37.409Z'},
#   {'id': 729036,
#    'name': 'CoupDur',
#    'height': 32,
#    'width': 30,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 35055, 'name': 'adidino', 'display_name': 'Adidino'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729036/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729036/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729036/4'},
#    'status': 1,
#    'usage_count': 0,
#    'created_at': '2023-05-29T22:05:08.032Z',
#    'last_updated': '2023-05-30T13:45:37.409Z'},
#   {'id': 729031,
#    'name': 'TheCheeseball',
#    'height': 28,
#    'width': 28,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 370821,
#     'name': 'thecheeseball81',
#     'display_name': 'TheCheeseball81'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729031/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729031/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729031/4'},
#    'status': 1,
#    'usage_count': 1,
#    'created_at': '2023-05-29T17:46:57.344Z',
#    'last_updated': '2023-05-30T13:45:37.409Z'},
#   {'id': 729030,
#    'name': 'DerpyBarbaLBD',
#    'height': 28,
#    'width': 28,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 370821,
#     'name': 'thecheeseball81',
#     'display_name': 'TheCheeseball81'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729030/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729030/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729030/4'},
#    'status': 1,
#    'usage_count': 1,
#    'created_at': '2023-05-29T17:44:31.529Z',
#    'last_updated': '2023-05-30T13:46:34.791Z'},
#   {'id': 729028,
#    'name': 'DonkNarcissist',
#    'height': 32,
#    'width': 48,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1076774,
#     'name': 'goodpostureisgoodforyou',
#     'display_name': 'GoodPostureIsGoodForYou'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729028/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729028/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729028/4'},
#    'status': 1,
#    'usage_count': 0,
#    'created_at': '2023-05-29T15:51:50.885Z',
#    'last_updated': '2023-05-30T13:45:37.409Z'},
#   {'id': 729027,
#    'name': 'pepeDelusional',
#    'height': 32,
#    'width': 57,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1076774,
#     'name': 'goodpostureisgoodforyou',
#     'display_name': 'GoodPostureIsGoodForYou'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729027/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729027/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729027/4'},
#    'status': 1,
#    'usage_count': 0,
#    'created_at': '2023-05-29T15:51:50.875Z',
#    'last_updated': '2023-05-30T13:45:37.409Z'},
#   {'id': 729026,
#    'name': 'Piratega',
#    'height': 32,
#    'width': 40,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1540993,
#     'name': 'captainsparg',
#     'display_name': 'CaptainSparg'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729026/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729026/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729026/4'},
#    'status': 1,
#    'usage_count': 0,
#    'created_at': '2023-05-29T12:29:55.175Z',
#    'last_updated': '2023-05-30T13:45:37.409Z'},
#   {'id': 729025,
#    'name': 'PirateBlind',
#    'height': 32,
#    'width': 40,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1540993,
#     'name': 'captainsparg',
#     'display_name': 'CaptainSparg'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729025/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729025/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729025/4'},
#    'status': 1,
#    'usage_count': 0,
#    'created_at': '2023-05-29T12:28:26.691Z',
#    'last_updated': '2023-05-30T13:45:37.409Z'},
#   {'id': 729024,
#    'name': 'PepeKnight',
#    'height': 32,
#    'width': 44,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1305160,
#     'name': '1namelessagent',
#     'display_name': '1NamelessAgent'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729024/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729024/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729024/4'},
#    'status': 1,
#    'usage_count': 5,
#    'created_at': '2023-05-29T12:09:05.551Z',
#    'last_updated': '2023-05-29T12:14:40.625Z'},
#   {'id': 729023,
#    'name': 'gecoHappy',
#    'height': 28,
#    'width': 28,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1429339,
#     'name': 'purple_geco',
#     'display_name': 'Purple_Geco'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729023/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729023/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729023/4'},
#    'status': 1,
#    'usage_count': 1,
#    'created_at': '2023-05-29T09:22:19.843Z',
#    'last_updated': '2023-05-29T12:10:16.619Z'},
#   {'id': 729022,
#    'name': 'gecoSip',
#    'height': 28,
#    'width': 28,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1429339,
#     'name': 'purple_geco',
#     'display_name': 'Purple_Geco'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729022/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729022/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729022/4'},
#    'status': 1,
#    'usage_count': 1,
#    'created_at': '2023-05-29T09:17:44.496Z',
#    'last_updated': '2023-05-29T12:10:16.619Z'},
#   {'id': 729021,
#    'name': 'gecoCozy',
#    'height': 28,
#    'width': 28,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1429339,
#     'name': 'purple_geco',
#     'display_name': 'Purple_Geco'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729021/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729021/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729021/4'},
#    'status': 1,
#    'usage_count': 1,
#    'created_at': '2023-05-29T09:17:44.490Z',
#    'last_updated': '2023-05-29T12:10:16.619Z'},
#   {'id': 729019,
#    'name': 'ppR',
#    'height': 28,
#    'width': 36,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 952340, 'name': 'drousyk', 'display_name': 'drousyk'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729019/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729019/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729019/4'},
#    'status': 1,
#    'usage_count': 1,
#    'created_at': '2023-05-29T08:59:56.183Z',
#    'last_updated': '2023-05-29T11:57:29.234Z'},
#   {'id': 729017,
#    'name': 'ryeSunsus',
#    'height': 32,
#    'width': 32,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 717353, 'name': 'ryemanni', 'display_name': 'Ryemanni'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729017/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729017/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729017/4'},
#    'status': 1,
#    'usage_count': 2,
#    'created_at': '2023-05-29T07:53:01.132Z',
#    'last_updated': '2023-05-29T11:57:29.234Z'},
#   {'id': 729016,
#    'name': 'AYOOO',
#    'height': 28,
#    'width': 37,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 412757, 'name': 'fcmtom16', 'display_name': 'FCMtom16'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729016/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729016/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729016/4'},
#    'animated': {'1': 'https://cdn.frankerfacez.com/emote/729016/animated/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729016/animated/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729016/animated/4'},
#    'status': 1,
#    'usage_count': 3,
#    'created_at': '2023-05-29T07:49:54.975Z',
#    'last_updated': '2023-05-29T11:57:29.234Z'},
#   {'id': 729015,
#    'name': 'AYOOO',
#    'height': 28,
#    'width': 37,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 412757, 'name': 'fcmtom16', 'display_name': 'FCMtom16'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729015/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729015/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729015/4'},
#    'animated': {'1': 'https://cdn.frankerfacez.com/emote/729015/animated/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729015/animated/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729015/animated/4'},
#    'status': 1,
#    'usage_count': 1,
#    'created_at': '2023-05-29T07:33:12.062Z',
#    'last_updated': '2023-05-29T11:57:29.234Z'},
#   {'id': 729014,
#    'name': 'EYE',
#    'height': 32,
#    'width': 50,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 848770,
#     'name': 'minhcredible',
#     'display_name': 'minhcredible'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729014/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729014/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729014/4'},
#    'status': 1,
#    'usage_count': 1,
#    'created_at': '2023-05-29T07:32:21.457Z',
#    'last_updated': '2023-05-29T11:57:29.234Z'},
#   {'id': 729012,
#    'name': 'ChestGrab',
#    'height': 28,
#    'width': 24,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1541011,
#     'name': 'tessalatte',
#     'display_name': 'tessalatte'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729012/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729012/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729012/4'},
#    'status': 1,
#    'usage_count': 1,
#    'created_at': '2023-05-29T06:14:05.540Z',
#    'last_updated': '2023-05-29T11:57:29.234Z'},
#   {'id': 729011,
#    'name': 'Bonk',
#    'height': 32,
#    'width': 32,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1457594,
#     'name': 'cutealice12',
#     'display_name': 'cutealice12'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729011/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729011/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729011/4'},
#    'status': 1,
#    'usage_count': 1,
#    'created_at': '2023-05-29T05:08:49.838Z',
#    'last_updated': '2023-05-29T11:57:29.234Z'},
#   {'id': 729010,
#    'name': 'OnlyFans',
#    'height': 32,
#    'width': 32,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1532353,
#     'name': 'arcaneaceles',
#     'display_name': 'ArcaneAceles'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729010/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729010/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729010/4'},
#    'animated': {'1': 'https://cdn.frankerfacez.com/emote/729010/animated/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729010/animated/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729010/animated/4'},
#    'status': 1,
#    'usage_count': 1,
#    'created_at': '2023-05-29T04:48:06.130Z',
#    'last_updated': '2023-05-29T11:57:29.234Z'},
#   {'id': 729009,
#    'name': 'MommySorry',
#    'height': 28,
#    'width': 28,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1532353,
#     'name': 'arcaneaceles',
#     'display_name': 'ArcaneAceles'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729009/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729009/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729009/4'},
#    'animated': {'1': 'https://cdn.frankerfacez.com/emote/729009/animated/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729009/animated/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729009/animated/4'},
#    'status': 1,
#    'usage_count': 2,
#    'created_at': '2023-05-29T04:48:03.577Z',
#    'last_updated': '2023-05-29T11:57:29.234Z'},
#   {'id': 729008,
#    'name': 'BirthdayBalloons',
#    'height': 32,
#    'width': 32,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1532353,
#     'name': 'arcaneaceles',
#     'display_name': 'ArcaneAceles'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729008/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729008/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729008/4'},
#    'animated': {'1': 'https://cdn.frankerfacez.com/emote/729008/animated/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729008/animated/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729008/animated/4'},
#    'status': 1,
#    'usage_count': 1,
#    'created_at': '2023-05-29T04:48:03.362Z',
#    'last_updated': '2023-05-29T11:57:29.234Z'},
#   {'id': 729007,
#    'name': 'DaddySorry',
#    'height': 28,
#    'width': 28,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1532353,
#     'name': 'arcaneaceles',
#     'display_name': 'ArcaneAceles'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729007/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729007/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729007/4'},
#    'animated': {'1': 'https://cdn.frankerfacez.com/emote/729007/animated/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729007/animated/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729007/animated/4'},
#    'status': 1,
#    'usage_count': 1,
#    'created_at': '2023-05-29T04:48:02.841Z',
#    'last_updated': '2023-05-29T11:57:29.234Z'},
#   {'id': 729006,
#    'name': 'WeSayGay',
#    'height': 28,
#    'width': 28,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1532353,
#     'name': 'arcaneaceles',
#     'display_name': 'ArcaneAceles'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/729006/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729006/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729006/4'},
#    'animated': {'1': 'https://cdn.frankerfacez.com/emote/729006/animated/1',
#     '2': 'https://cdn.frankerfacez.com/emote/729006/animated/2',
#     '4': 'https://cdn.frankerfacez.com/emote/729006/animated/4'},
#    'status': 1,
#    'usage_count': 1,
#    'created_at': '2023-05-29T04:48:02.221Z',
#    'last_updated': '2023-05-29T11:57:29.234Z'},
#   {'id': 728977,
#    'name': 'peepoSad',
#    'height': 32,
#    'width': 32,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1523669,
#     'name': 'night_lovei',
#     'display_name': 'night_loveI'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/728977/1',
#     '2': 'https://cdn.frankerfacez.com/emote/728977/2',
#     '4': 'https://cdn.frankerfacez.com/emote/728977/4'},
#    'status': 1,
#    'usage_count': 1,
#    'created_at': '2023-05-28T21:58:45.678Z',
#    'last_updated': '2023-05-29T11:57:29.234Z'},
#   {'id': 728975,
#    'name': 'Boofd',
#    'height': 18,
#    'width': 18,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1543203, 'name': 'caspaboo', 'display_name': 'CaspABoO'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/728975/1',
#     '2': 'https://cdn.frankerfacez.com/emote/728975/2',
#     '4': 'https://cdn.frankerfacez.com/emote/728975/4'},
#    'animated': {'1': 'https://cdn.frankerfacez.com/emote/728975/animated/1',
#     '2': 'https://cdn.frankerfacez.com/emote/728975/animated/2',
#     '4': 'https://cdn.frankerfacez.com/emote/728975/animated/4'},
#    'status': 1,
#    'usage_count': 1,
#    'created_at': '2023-05-28T21:27:59.037Z',
#    'last_updated': '2023-05-29T11:57:29.234Z'},
#   {'id': 728972,
#    'name': 'FIRE',
#    'height': 28,
#    'width': 28,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1543203, 'name': 'caspaboo', 'display_name': 'CaspABoO'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/728972/1',
#     '2': 'https://cdn.frankerfacez.com/emote/728972/2',
#     '4': 'https://cdn.frankerfacez.com/emote/728972/4'},
#    'animated': {'1': 'https://cdn.frankerfacez.com/emote/728972/animated/1',
#     '2': 'https://cdn.frankerfacez.com/emote/728972/animated/2',
#     '4': 'https://cdn.frankerfacez.com/emote/728972/animated/4'},
#    'status': 1,
#    'usage_count': 1,
#    'created_at': '2023-05-28T21:27:58.434Z',
#    'last_updated': '2023-05-29T11:57:29.234Z'},
#   {'id': 728971,
#    'name': 'Ooh',
#    'height': 18,
#    'width': 18,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1543203, 'name': 'caspaboo', 'display_name': 'CaspABoO'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/728971/1',
#     '2': 'https://cdn.frankerfacez.com/emote/728971/2',
#     '4': 'https://cdn.frankerfacez.com/emote/728971/4'},
#    'animated': {'1': 'https://cdn.frankerfacez.com/emote/728971/animated/1',
#     '2': 'https://cdn.frankerfacez.com/emote/728971/animated/2',
#     '4': 'https://cdn.frankerfacez.com/emote/728971/animated/4'},
#    'status': 1,
#    'usage_count': 1,
#    'created_at': '2023-05-28T21:27:58.241Z',
#    'last_updated': '2023-05-29T11:57:29.234Z'},
#   {'id': 728970,
#    'name': 'smugLan',
#    'height': 24,
#    'width': 24,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 243697,
#     'name': 'thatqpixel',
#     'display_name': 'thatQPixel'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/728970/1',
#     '2': 'https://cdn.frankerfacez.com/emote/728970/2',
#     '4': 'https://cdn.frankerfacez.com/emote/728970/4'},
#    'status': 1,
#    'usage_count': 1,
#    'created_at': '2023-05-28T20:45:44.015Z',
#    'last_updated': '2023-05-29T11:51:01.674Z'},
#   {'id': 728969,
#    'name': 'FuckOff',
#    'height': 32,
#    'width': 27,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 468645,
#     'name': 'theloveslug',
#     'display_name': 'TheLoveSlug'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/728969/1',
#     '2': 'https://cdn.frankerfacez.com/emote/728969/2',
#     '4': 'https://cdn.frankerfacez.com/emote/728969/4'},
#    'status': 1,
#    'usage_count': 2,
#    'created_at': '2023-05-28T20:05:47.012Z',
#    'last_updated': '2023-05-29T11:51:01.674Z'},
#   {'id': 728968,
#    'name': 'BOZO',
#    'height': 32,
#    'width': 32,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1542981, 'name': 'phoody64', 'display_name': 'phoody64'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/728968/1',
#     '2': 'https://cdn.frankerfacez.com/emote/728968/2',
#     '4': 'https://cdn.frankerfacez.com/emote/728968/4'},
#    'status': 1,
#    'usage_count': 0,
#    'created_at': '2023-05-28T19:42:21.481Z',
#    'last_updated': '2023-05-29T11:51:01.674Z'},
#   {'id': 728967,
#    'name': 'YoNap',
#    'height': 25,
#    'width': 25,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 72497, 'name': 'ffviplayer', 'display_name': 'Ffviplayer'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/728967/1',
#     '2': 'https://cdn.frankerfacez.com/emote/728967/2',
#     '4': 'https://cdn.frankerfacez.com/emote/728967/4'},
#    'status': 1,
#    'usage_count': 1,
#    'created_at': '2023-05-28T19:29:12.931Z',
#    'last_updated': '2023-05-29T11:51:01.674Z'},
#   {'id': 728962,
#    'name': 'Sheeesh',
#    'height': 28,
#    'width': 28,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1477707, 'name': 'nyxtesy', 'display_name': 'Nyxtesy'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/728962/1',
#     '2': 'https://cdn.frankerfacez.com/emote/728962/2',
#     '4': 'https://cdn.frankerfacez.com/emote/728962/4'},
#    'status': 1,
#    'usage_count': 1,
#    'created_at': '2023-05-28T19:21:41.300Z',
#    'last_updated': '2023-05-29T11:51:01.674Z'},
#   {'id': 728958,
#    'name': '200IQ',
#    'height': 28,
#    'width': 28,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1477707, 'name': 'nyxtesy', 'display_name': 'Nyxtesy'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/728958/1',
#     '2': 'https://cdn.frankerfacez.com/emote/728958/2',
#     '4': 'https://cdn.frankerfacez.com/emote/728958/4'},
#    'status': 1,
#    'usage_count': 1,
#    'created_at': '2023-05-28T19:20:49.845Z',
#    'last_updated': '2023-05-29T11:51:01.674Z'},
#   {'id': 728957,
#    'name': 'GetClapped',
#    'height': 28,
#    'width': 28,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1477707, 'name': 'nyxtesy', 'display_name': 'Nyxtesy'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/728957/1',
#     '2': 'https://cdn.frankerfacez.com/emote/728957/2',
#     '4': 'https://cdn.frankerfacez.com/emote/728957/4'},
#    'status': 1,
#    'usage_count': 1,
#    'created_at': '2023-05-28T19:20:49.835Z',
#    'last_updated': '2023-05-29T11:51:01.674Z'},
#   {'id': 728956,
#    'name': 'GGs',
#    'height': 28,
#    'width': 28,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 1477707, 'name': 'nyxtesy', 'display_name': 'Nyxtesy'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/728956/1',
#     '2': 'https://cdn.frankerfacez.com/emote/728956/2',
#     '4': 'https://cdn.frankerfacez.com/emote/728956/4'},
#    'status': 1,
#    'usage_count': 3,
#    'created_at': '2023-05-28T19:20:49.793Z',
#    'last_updated': '2023-05-29T11:51:01.674Z'},
#   {'id': 728918,
#    'name': 'peepoDisgust',
#    'height': 32,
#    'width': 32,
#    'public': True,
#    'hidden': False,
#    'modifier': False,
#    'modifier_flags': 0,
#    'offset': None,
#    'margins': None,
#    'css': None,
#    'owner': {'_id': 236965,
#     'name': 'trippycolour',
#     'display_name': 'TrippyColour'},
#    'artist': None,
#    'urls': {'1': 'https://cdn.frankerfacez.com/emote/728918/1',
#     '2': 'https://cdn.frankerfacez.com/emote/728918/2',
#     '4': 'https://cdn.frankerfacez.com/emote/728918/4'},
#    'status': 1,
#    'usage_count': 0,
#    'created_at': '2023-05-28T16:29:15.307Z',
#    'last_updated': '2023-05-28T17:54:53.825Z'}]}

# %%
req = requests.request('GET', 'https://cdn.frankerfacez.com/emote/729024/4')
Image.open(BytesIO(req.content))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=176x128>
